# %%
import pandas as pd

# %%
pd.read_csv('Annual_survey.csv')#importing data frame/csv file
# Out:
#          Year Industry_aggregation_NZSIOC  Industry_code_NZSIOC  \
# 0      2021.0                     Level 1               99999.0
# 1      2021.0                     Level 1               99999.0
# 2      2021.0                     Level 1               99999.0
# 3      2021.0                     Level 1               99999.0
# 4      2021.0                     Level 1               99999.0
# ...       ...                         ...                   ...
# 41704     NaN                         NaN                   NaN
# 41705     NaN                         NaN                   NaN
# 41706     NaN                         NaN                   NaN
# 41707     NaN                         NaN                   NaN
# 41708     NaN                         NaN                   NaN
#
#       Industry_name_NZSIOC               Units Variable_code  \
# 0           All industries  Dollars (millions)           H01
# 1           All industries  Dollars (millions)           H04
# ...

# %%
#NaN - if a column contains NaN, the whole column type must be floating point
AnnualData = pd.read_csv('Annual_survey.csv')
AnnualData
# Out:
#          Year Industry_aggregation_NZSIOC  Industry_code_NZSIOC  \
# 0      2021.0                     Level 1               99999.0
# 1      2021.0                     Level 1               99999.0
# 2      2021.0                     Level 1               99999.0
# 3      2021.0                     Level 1               99999.0
# 4      2021.0                     Level 1               99999.0
# ...       ...                         ...                   ...
# 41704     NaN                         NaN                   NaN
# 41705     NaN                         NaN                   NaN
# 41706     NaN                         NaN                   NaN
# 41707     NaN                         NaN                   NaN
# 41708     NaN                         NaN                   NaN
#
#       Industry_name_NZSIOC               Units Variable_code  \
# 0           All industries  Dollars (millions)           H01
# 1           All industries  Dollars (millions)           H04
# ...
