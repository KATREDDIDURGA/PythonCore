# %%
import pandas as pd

# %%
s = pd.read_csv('Annual_survey.csv')
s.head(5)
# Out:
#      Year Industry_aggregation_NZSIOC  Industry_code_NZSIOC  \
# 0  2021.0                     Level 1               99999.0
# 1  2021.0                     Level 1               99999.0
# 2  2021.0                     Level 1               99999.0
# 3  2021.0                     Level 1               99999.0
# 4  2021.0                     Level 1               99999.0
#
#   Industry_name_NZSIOC               Units Variable_code  \
# 0       All industries  Dollars (millions)           H01
# 1       All industries  Dollars (millions)           H04
# 2       All industries  Dollars (millions)           H05
# 3       All industries  Dollars (millions)           H07
# 4       All industries  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
s.drop_duplicates()
# Out:
#       Year Industry_aggregation_NZSIOC  Industry_code_NZSIOC  \
# 0   2021.0                     Level 1               99999.0
# 1   2021.0                     Level 1               99999.0
# 2   2021.0                     Level 1               99999.0
# 3   2021.0                     Level 1               99999.0
# 4   2021.0                     Level 1               99999.0
# 5   2021.0                     Level 1               99999.0
# 6   2021.0                     Level 1               99999.0
# 7   2021.0                     Level 1               99999.0
# 8   2021.0                     Level 1               99999.0
# 9   2021.0                     Level 1               99999.0
# 10  2021.0                     Level 1               99999.0
# 11  2021.0                     Level 1               99999.0
# 12  2021.0                     Level 1               99999.0
# 13  2021.0                     Level 1               99999.0
# ...

# %%
s['City'] = "Hyderabad"

thisdict = {
  "Hyderabad": "TS",
  "Secunderabad": "Mustang",
  "year": "ghj"
}

s.vlookup('City',"thisdict")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [26], in <cell line: 9>()
#       1 s['City'] = "Hyderabad"
#       3 thisdict = {
#       4   "Hyderabad": "TS",
#       5   "Secunderabad": "Mustang",
#       6   "year": "ghj"
#       7 }
# ----> 9 s.vlookup('City',"thisdict")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'vlookup'

# %%
s['NewSalary'] = s['Salary'].sub(50000)

# %%
s.head()
# Out:
#          Year Industry_aggregation_NZSIOC  Industry_code_NZSIOC  \
# 0      2021.0                     Level 1               99999.0
# 1      2021.0                     Level 1               99999.0
# 2      2021.0                     Level 1               99999.0
# 3      2021.0                     Level 1               99999.0
# 4      2021.0                     Level 1               99999.0
# ...       ...                         ...                   ...
# 41704     NaN                         NaN                   NaN
# 41705     NaN                         NaN                   NaN
# 41706     NaN                         NaN                   NaN
# 41707     NaN                         NaN                   NaN
# 41708     NaN                         NaN                   NaN
#
#       Industry_name_NZSIOC               Units Variable_code  \
# 0           All industries  Dollars (millions)           H01
# 1           All industries  Dollars (millions)           H04
# ...

# %%
s['NewSalary'] = 0.453243

# %%
s['NewSalary'].mul(0.76478)
# Out:
# 0        0.346631
# 1        0.346631
# 2        0.346631
# 3        0.346631
# 4        0.346631
#            ...
# 41704    0.346631
# 41705    0.346631
# 41706    0.346631
# 41707    0.346631
# 41708    0.346631
# Name: NewSalary, Length: 41709, dtype: float64

# %%
s.head()
# Out:
#      Year Industry_aggregation_NZSIOC  Industry_code_NZSIOC  \
# 0  2021.0                     Level 1               99999.0
# 1  2021.0                     Level 1               99999.0
# 2  2021.0                     Level 1               99999.0
# 3  2021.0                     Level 1               99999.0
# 4  2021.0                     Level 1               99999.0
#
#   Industry_name_NZSIOC               Units Variable_code  \
# 0       All industries  Dollars (millions)           H01
# 1       All industries  Dollars (millions)           H04
# 2       All industries  Dollars (millions)           H05
# 3       All industries  Dollars (millions)           H07
# 4       All industries  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
s['Age'] = 30
s
# Out:
#          Year Industry_aggregation_NZSIOC  Industry_code_NZSIOC  \
# 0      2021.0                     Level 1               99999.0
# 1      2021.0                     Level 1               99999.0
# 2      2021.0                     Level 1               99999.0
# 3      2021.0                     Level 1               99999.0
# 4      2021.0                     Level 1               99999.0
# ...       ...                         ...                   ...
# 41704     NaN                         NaN                   NaN
# 41705     NaN                         NaN                   NaN
# 41706     NaN                         NaN                   NaN
# 41707     NaN                         NaN                   NaN
# 41708     NaN                         NaN                   NaN
#
#       Industry_name_NZSIOC               Units Variable_code  \
# 0           All industries  Dollars (millions)           H01
# 1           All industries  Dollars (millions)           H04
# ...

# %%
s[s.Age<29].head()
# Out:
# Empty DataFrame
# Columns: [Year, Industry_aggregation_NZSIOC, Industry_code_NZSIOC, Industry_name_NZSIOC, Units, Variable_code, Variable_name, Variable_category, Value, Industry_code_ANZSIC06, Age]
# Index: []

# %%
s.drop_duplicates()
# Out:
#       Year Industry_aggregation_NZSIOC  Industry_code_NZSIOC  \
# 0   2021.0                     Level 1               99999.0
# 1   2021.0                     Level 1               99999.0
# 2   2021.0                     Level 1               99999.0
# 3   2021.0                     Level 1               99999.0
# 4   2021.0                     Level 1               99999.0
# 5   2021.0                     Level 1               99999.0
# 6   2021.0                     Level 1               99999.0
# 7   2021.0                     Level 1               99999.0
# 8   2021.0                     Level 1               99999.0
# 9   2021.0                     Level 1               99999.0
# 10  2021.0                     Level 1               99999.0
# 11  2021.0                     Level 1               99999.0
# 12  2021.0                     Level 1               99999.0
# 13  2021.0                     Level 1               99999.0
# ...

# %%
s['Year']
# Out:
# 0        2021.0
# 1        2021.0
# 2        2021.0
# 3        2021.0
# 4        2021.0
#           ...
# 41704       NaN
# 41705       NaN
# 41706       NaN
# 41707       NaN
# 41708       NaN
# Name: Year, Length: 41709, dtype: float64

# %%
# import pandas as pd
import pandas as pd
 
# import numpy as np
import numpy as np
 
# simple array
data = np.array(['g','e','e','k','s'])
data1 = np.array(['d','o','sd','ka','ashds'])
ser = pd.Series(data)
ser1 = pd.Series(data1)

print(pd.concat([ser,ser1],axis = 1))
ser1.reindex(ser)
# Out:
#    0      1
# 0  g      d
# 1  e      o
# 2  e     sd
# 3  k     ka
# 4  s  ashds
# g    NaN
# e    NaN
# e    NaN
# k    NaN
# s    NaN
# dtype: object
