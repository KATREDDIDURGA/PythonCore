# %%
import pandas as pd

# %%
s = pd.read_csv('Annual_survey.csv')
s.head(5)
# Out:
#      Year Industry_aggregation_NZSIOC  Industry_code_NZSIOC  \
# 0  2021.0                     Level 1               99999.0
# 1  2021.0                     Level 1               99999.0
# 2  2021.0                     Level 1               99999.0
# 3  2021.0                     Level 1               99999.0
# 4  2021.0                     Level 1               99999.0
#
#   Industry_name_NZSIOC               Units Variable_code  \
# 0       All industries  Dollars (millions)           H01
# 1       All industries  Dollars (millions)           H04
# 2       All industries  Dollars (millions)           H05
# 3       All industries  Dollars (millions)           H07
# 4       All industries  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
s['Year'].head()#syntax for reading the column
# Out:
# 0    2021.0
# 1    2021.0
# 2    2021.0
# 3    2021.0
# 4    2021.0
# Name: Year, dtype: float64

# %%
s['Sport'] = 'BasketBall'
s.head()
# Out:
#      Year Industry_aggregation_NZSIOC  Industry_code_NZSIOC  \
# 0  2021.0                     Level 1               99999.0
# 1  2021.0                     Level 1               99999.0
# 2  2021.0                     Level 1               99999.0
# 3  2021.0                     Level 1               99999.0
# 4  2021.0                     Level 1               99999.0
#
#   Industry_name_NZSIOC               Units Variable_code  \
# 0       All industries  Dollars (millions)           H01
# 1       All industries  Dollars (millions)           H04
# 2       All industries  Dollars (millions)           H05
# 3       All industries  Dollars (millions)           H07
# 4       All industries  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
s['League'] = 'National Basketball Association'
s.head()
# Out:
#      Year Industry_aggregation_NZSIOC  Industry_code_NZSIOC  \
# 0  2021.0                     Level 1               99999.0
# 1  2021.0                     Level 1               99999.0
# 2  2021.0                     Level 1               99999.0
# 3  2021.0                     Level 1               99999.0
# 4  2021.0                     Level 1               99999.0
#
#   Industry_name_NZSIOC               Units Variable_code  \
# 0       All industries  Dollars (millions)           H01
# 1       All industries  Dollars (millions)           H04
# 2       All industries  Dollars (millions)           H05
# 3       All industries  Dollars (millions)           H07
# 4       All industries  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
s = pd.read_csv('Annual_survey.csv')
s.head(5)
# Out:
#      Year Industry_aggregation_NZSIOC  Industry_code_NZSIOC  \
# 0  2021.0                     Level 1               99999.0
# 1  2021.0                     Level 1               99999.0
# 2  2021.0                     Level 1               99999.0
# 3  2021.0                     Level 1               99999.0
# 4  2021.0                     Level 1               99999.0
#
#   Industry_name_NZSIOC               Units Variable_code  \
# 0       All industries  Dollars (millions)           H01
# 1       All industries  Dollars (millions)           H04
# 2       All industries  Dollars (millions)           H05
# 3       All industries  Dollars (millions)           H07
# 4       All industries  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
s.insert(loc =3,column = "part", value = "First")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 s.insert(0, 'a', -1)
#       2 s.head(5)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4440, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    4434     raise ValueError(
#    4435         "Cannot specify 'allow_duplicates=True' when "
#    4436         "'self.flags.allows_duplicate_labels' is False."
#    4437     )
#    4438 if not allow_duplicates and column in self.columns:
#    4439     # Should this be a different kind of error??
# -> 4440     raise ValueError(f"cannot insert {column}, already exists")
#    4441 if not isinstance(loc, int):
#    4442     raise TypeError("loc must be int")
#
# ValueError: cannot insert a, already exists

# %%
s.head()
# Out:
#    a    Year Industry_aggregation_NZSIOC  Industry_code_NZSIOC   part  \
# 0 -1  2021.0                     Level 1               99999.0  First
# 1 -1  2021.0                     Level 1               99999.0  First
# 2 -1  2021.0                     Level 1               99999.0  First
# 3 -1  2021.0                     Level 1               99999.0  First
# 4 -1  2021.0                     Level 1               99999.0  First
#
#         Sport Industry_name_NZSIOC               Units Variable_code  \
# 0  BasketBall       All industries  Dollars (millions)           H01
# 1  BasketBall       All industries  Dollars (millions)           H04
# 2  BasketBall       All industries  Dollars (millions)           H05
# 3  BasketBall       All industries  Dollars (millions)           H07
# 4  BasketBall       All industries  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# ...

# %%
s.insert(loc = 7, column = 'Leak',value = 'yes')

# %%
s.head()
# Out:
#    a    Year Industry_aggregation_NZSIOC  Industry_code_NZSIOC   part  \
# 0 -1  2021.0                     Level 1               99999.0  First
# 1 -1  2021.0                     Level 1               99999.0  First
# 2 -1  2021.0                     Level 1               99999.0  First
# 3 -1  2021.0                     Level 1               99999.0  First
# 4 -1  2021.0                     Level 1               99999.0  First
#
#         Sport Industry_name_NZSIOC Leak               Units Variable_code  \
# 0  BasketBall       All industries  yes  Dollars (millions)           H01
# 1  BasketBall       All industries  yes  Dollars (millions)           H04
# 2  BasketBall       All industries  yes  Dollars (millions)           H05
# 3  BasketBall       All industries  yes  Dollars (millions)           H07
# 4  BasketBall       All industries  yes  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# ...
