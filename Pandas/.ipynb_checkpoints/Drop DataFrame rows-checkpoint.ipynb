# %%
import pandas as pd

# %%
s = pd.read_csv('Annual_survey.csv')
s.head()
# Out:
#      Year Industry_aggregation_NZSIOC  Industry_code_NZSIOC  \
# 0  2021.0                     Level 1               99999.0
# 1  2021.0                     Level 1               99999.0
# 2  2021.0                     Level 1               99999.0
# 3  2021.0                     Level 1               99999.0
# 4  2021.0                     Level 1               99999.0
#
#   Industry_name_NZSIOC               Units Variable_code  \
# 0       All industries  Dollars (millions)           H01
# 1       All industries  Dollars (millions)           H04
# 2       All industries  Dollars (millions)           H05
# 3       All industries  Dollars (millions)           H07
# 4       All industries  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
s[['Year','Value']].head()
# Out:
#      Year     Value
# 0  2021.0  7,57,504
# 1  2021.0  6,74,890
# 2  2021.0    49,593
# 3  2021.0    33,020
# 4  2021.0  6,54,404

# %%
s.dropna()
no_empty_rows = s.dropna(how = "any")#remove with any row with atleast one NaN
s.dropna(how = 'all')# if we want to remove a row with all NaN
#s.dropna(subset = ['columna','columnb'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [13], in <cell line: 4>()
#       2 no_empty_rows = s.dropna(how = "any")#remove with any row with atleast one NaN
#       3 s.dropna(how = 'all')# if we want to remove a row with all NaN
# ----> 4 s.dropna(subset = ['columna','columnb'])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
s.dropna(subset=['Year']) # removes the rows if that column contains NaN
# Out:
#       Year Industry_aggregation_NZSIOC  Industry_code_NZSIOC  \
# 0   2021.0                     Level 1               99999.0
# 1   2021.0                     Level 1               99999.0
# 2   2021.0                     Level 1               99999.0
# 3   2021.0                     Level 1               99999.0
# 4   2021.0                     Level 1               99999.0
# 5   2021.0                     Level 1               99999.0
# 6   2021.0                     Level 1               99999.0
# 7   2021.0                     Level 1               99999.0
# 8   2021.0                     Level 1               99999.0
# 9   2021.0                     Level 1               99999.0
# 10  2021.0                     Level 1               99999.0
# 11  2021.0                     Level 1               99999.0
# 12  2021.0                     Level 1               99999.0
# 13  2021.0                     Level 1               99999.0
# ...

# %%
import pandas as pd
data = pd.read_csv
