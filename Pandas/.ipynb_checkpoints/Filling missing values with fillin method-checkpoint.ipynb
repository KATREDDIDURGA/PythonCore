# %%
import pandas as pd

# %%
s = pd.read_csv('AnnualRevenue.csv')
s.head()
# Out:
#      Year Industry_aggregation_NZSIOC  Industry_code_NZSIOC  \
# 0  2021.0                     Level 1               99999.0
# 1  2021.0                     Level 1               99999.0
# 2     NaN                         NaN                   NaN
# 3  2021.0                     Level 1               99999.0
# 4  2021.0                     Level 1               99999.0
#
#   Industry_name_NZSIOC     Units Variable_code Variable_name  \
# 0       All industries  Dollars            H01             a
# 1       All industries  Dollars            H04             a
# 2                  NaN  Dollars            NaN             a
# 3       All industries  Dollars            H07             a
# 4       All industries  Dollars            H08             a
#
#   Variable_category     Value Industry_code_ANZSIC06
# 0         Financial  7,57,504                  K6330
# 1         Financial  6,74,890                  L6711
# 2         Financial       NaN                  O7552
# ...

# %%
s.fillna('0')
s['Year'].fillna('Unknown')# to just visualize what happens by sampling that column and performing the operation
s['Year'].fillna('Unknown',inplace = True)#to make change on the original data frame
#inplace is not recommended
s['Year'] = s['Year'].fillna('Unknown')#recommended

# %%
s
# Out:
#        Year Industry_aggregation_NZSIOC  Industry_code_NZSIOC  \
# 0    2021.0                     Level 1               99999.0
# 1    2021.0                     Level 1               99999.0
# 2   Unknown                         NaN                   NaN
# 3    2021.0                     Level 1               99999.0
# 4    2021.0                     Level 1               99999.0
# 5    2021.0                     Level 1               99999.0
# 6    2021.0                     Level 1               99999.0
# 7    2021.0                     Level 1               99999.0
# 8    2021.0                     Level 1               99999.0
# 9    2021.0                     Level 1               99999.0
# 10   2021.0                     Level 1               99999.0
# 11   2021.0                     Level 1               99999.0
# 12   2021.0                     Level 1               99999.0
# 13   2021.0                     Level 1               99999.0
# ...
